# %%
# package imports
from regression_helper_functions import (least_squares, get_model_predictions,
                                        make_regression_graph, measure_error,
                                        process_life_expectancy_data)

# %% [markdown]
# We're giong to start with linear regression

# %%
x_data = [2, 3, 5, 7, 9]
y_data = [4, 5, 7, 10, 15]

# %%
m , b = least_squares([x_data, y_data])
# Out:
# Results of linear regression:
# m = 1.51829 c = 0.30488

# %%
y_pred = get_model_predictions(x_data, m, b)
print(y_pred)
# Out:
# [3.341463414634146, 4.859756097560975, 7.896341463414634, 10.932926829268293, 13.96951219512195]

# %%
make_regression_graph(x_data, y_data, get_model_predictions(x_data, m, b), ['X', 'Y'])

# %% [markdown]
# ### RMSE (Root Mean Squared Error)
#
# Measures error on the same scale as your target variable.
#
# 1. Calculate the sum of squred differences (SSE) between observed values of y and predicted values of y: SSE = (y-y_pred)**2
# 2. Convert the SSE into the mean-squared error by dividing by the total number of obervations, n, in our data: MSE = SSE/n
# 3. Take the square root of the MSE: RMSE = math.sqrt(MSE)

# %%
measure_error(y_data, y_pred)
# Out:
# 0.7986268703523449

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/gapminder-life-expectancy.csv', index_col='Life expectancy')
df.head()
# Out:
#                   1800   1801   1802   1803   1804   1805   1806   1807
# Life expectancy
# Afghanistan      28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14  \
# Albania          35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria          28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# American Samoa     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Andorra            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                   1808   1809  ...  2007  2008  2009  2010  2011  2012  2013
# Life expectancy                ...
# Afghanistan      28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  \
# Albania          35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7
# Algeria          28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3
# American Samoa     NaN    NaN  ...  72.4  72.7  71.3  72.8  72.6  72.6  72.7
# Andorra            NaN    NaN  ...  84.5  84.6  84.6  84.7  84.7  84.7  84.8
#
# ...

# %%
df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        ...
#        'West Bank and Gaza', 'West Germany', 'Western Sahara', 'Vietnam',
#        'Virgin Islands (U.S.)', 'Yemen', 'Zambia', 'Zimbabwe', 'Åland',
#        'South Sudan'],
#       dtype='object', name='Life expectancy', length=243)

# %%
m, c = process_life_expectancy_data('data/gapminder-life-expectancy.csv', "United Kingdom", [1950, 1980])
# Out:
# Results of linear regression:
# m = 0.13687 c = -197.61772
# Train RMSE = 0.32578

# %%
m, c = process_life_expectancy_data('data/gapminder-life-expectancy.csv', "United Kingdom", [1950, 1980], test_data_range=[2010, 2016])
# Out:
# Results of linear regression:
# m = 0.13687 c = -197.61772
# Train RMSE = 0.32578
# Test RMSE = 2.84829

# %% [markdown]
# What happens to the RMSE as you extend the training data set to include additional dates? Try out a couple of ranges. Explain observations

# %%
time_spans = [[1950, 1990], [1950, 2000], [1950, 2005], [1950, 2016], [1990, 2000]]

for t in time_spans:
    m, c = process_life_expectancy_data('data/gapminder-life-expectancy.csv', "United Kingdom", t, test_data_range=[2010, 2016])
# Out:
# Results of linear regression:
# m = 0.15457 c = -232.33617
# Train RMSE = 0.34205
# Test RMSE = 1.93525
# Results of linear regression:
# m = 0.16851 c = -259.73361
# Train RMSE = 0.37442
# Test RMSE = 1.26283
# Results of linear regression:
# m = 0.17434 c = -271.19052
# Train RMSE = 0.39464
# Test RMSE = 0.99863
# Results of linear regression:
# m = 0.18581 c = -293.78869
# Train RMSE = 0.44912
# Test RMSE = 0.51078
# Results of linear regression:
# m = 0.19727 c = -316.82273
# Train RMSE = 0.04733
# Test RMSE = 0.47524
